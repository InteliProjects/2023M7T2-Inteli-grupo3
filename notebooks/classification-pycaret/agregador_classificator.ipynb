# %% [markdown]
# # O objetivo deste notebook é realizar a leitura de arquivos parquets extraídos de um arquivo ZIP de uma única aeronave e agregar todos os arquivos .parquet em um único arquivo parquet

# %% [markdown]
# ### Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
import os
import dask.dataframe as dd

# %% [markdown]
# ### Leitura dos arquivos parquets

# %%
# Abrindo todos parquets para checar as falhas

directory = "C:/Users/eduar/Downloads/failures/"

dir_list = os.listdir(directory)

for file in dir_list:
    path = directory + file
    
    df = pd.read_parquet(path, engine='auto')


    columnA = "message0418DAA-1"
    columnB = "message0422DAA-1"
    column_a_unique = df["message0418DAA-1"].unique()
    column_b_unique = df["message0422DAA-1"].unique()


    print('parquet :', file, 'coluna a :',column_a_unique, 'coluna b :', column_b_unique)
# Out:
# parquet : TCRF_ARCHIVE_06120033_20220527183941.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220527212542.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220527234737.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220528013940.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220528053141.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220528084241.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220528125041.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220528153541.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220528182441.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220528233241.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220529023739.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220529102844.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220529194201.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220529194202.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220530132601.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220530132602.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220530132603.parquet coluna a : [nan  0.] coluna b : [nan  0.  5.  7.]
# parquet : TCRF_ARCHIVE_06120033_20220530132604.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220530153940.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220531210440.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220531232936.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220601013638.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220601052339.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220601081739.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220601105338.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220601130038.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220601151236.parquet coluna a : [nan  0.] coluna b : [nan  0.  5.  7.]
# parquet : TCRF_ARCHIVE_06120033_20220601171638.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220601211638.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220601234638.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220602054241.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220602094841.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220602131639.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220602153239.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220602183539.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220602214039.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220602233438.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220603013339.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220603051739.parquet coluna a : [nan  0.] coluna b : [nan  0.  5.  7.]
# parquet : TCRF_ARCHIVE_06120033_20220603084040.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220603104038.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220603123639.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220603142239.parquet coluna a : [nan  0.] coluna b : [nan  0.  5.  7.]
# parquet : TCRF_ARCHIVE_06120033_20220604101401.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220604101402.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220604101403.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20220604101404.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221030192539.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221030223441.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221031014640.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221031050541.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221031082141.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221031113541.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221031141941.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221031194239.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221031225444.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221101050341.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221101183944.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221101231844.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221229230544.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221230025742.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221231041001.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20221231041002.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20230713080505.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20230713080506.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20230713080507.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20230713105147.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20230713130144.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20230713150643.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20230713170043.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20230713225344.parquet coluna a : [nan  0.] coluna b : [nan  0.]
# parquet : TCRF_ARCHIVE_06120033_20230714010444.parquet coluna a : [nan  0.] coluna b : [nan  0.]

# %% [markdown]
# ### Concanteção dos arquivos parquets utilizando a API Dask considerando apenas as colunas filtradas

# %%
def concatenate_and_count_rows_in_parquet_files(file_path, filtered_cols):
    total_rows = 0
    list_of_dfs = []  # Lista para armazenar os DataFrames lidos

    # Lista de arquivos Parquet no diretório especificado
    parquet_files = [file for file in os.listdir(file_path) if file.endswith('.parquet')]

    # Loop para ler cada arquivo Parquet, contar as linhas e armazenar o DataFrame na lista
    for file_name in parquet_files:
        full_path = os.path.join(file_path, file_name)
        df = dd.read_parquet(full_path, columns=filtered_cols)
        total_rows += len(df)
        list_of_dfs.append(df)
        print(f"Arquivo {file_name} tem {len(df)} linhas.")

    # Concatenar todos os Dask DataFrames em um único Dask DataFrame
    concatenated_df = dd.concat(list_of_dfs, interleave_partitions=True)

    return concatenated_df, total_rows

# Uso da função
file_path = "C:/Users/eduar/Downloads/failures/"
filtered_cols = ['recording_time', 'dateDay-1', 'dateMonth-1', 'dateYear-1',
                 'phaseOfFlight-1', 'message0418DAA-1', 'message0422DAA-1', 
                 'bleedFavTmCmd-1a', 'bleedFavTmCmd-1b', 'bleedFavTmCmd-2a', 
                 'bleedFavTmCmd-2b', 'bleedFavTmFbk-1a', 'bleedFavTmFbk-1b', 
                 'bleedFavTmFbk-2b', 'bleedHprsovCmdStatus-1a', 'bleedHprsovCmdStatus-1b',
                 'bleedHprsovCmdStatus-2a', 'bleedHprsovCmdStatus-2b', 'bleedHprsovOpPosStatus-1a',
                 'bleedHprsovOpPosStatus-1b', 'bleedHprsovOpPosStatus-2a', 'bleedHprsovOpPosStatus-2b', 
                 'bleedMonPress-1a', 'bleedMonPress-1b', 'bleedMonPress-2a', 'bleedMonPress-2b', 
                 'bleedOnStatus-1a', 'bleedOnStatus-1b']



resulting_df, total_rows = concatenate_and_count_rows_in_parquet_files(file_path, filtered_cols)
print(f"O número total de linhas em todos os arquivos é: {total_rows}")
# Out:
# Arquivo TCRF_ARCHIVE_06120033_20220527183941.parquet tem 159741 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220527212542.parquet tem 157541 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220527234737.parquet tem 81301 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220528013940.parquet tem 84881 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220528053141.parquet tem 152241 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220528084241.parquet tem 178021 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220528125041.parquet tem 105941 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220528153541.parquet tem 129501 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220528182441.parquet tem 116541 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220528233241.parquet tem 122541 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220529023739.parquet tem 112561 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220529102844.parquet tem 122341 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220529194201.parquet tem 15201 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220529194202.parquet tem 112881 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220530132601.parquet tem 27461 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220530132602.parquet tem 10841 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220530132603.parquet tem 13981 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220530132604.parquet tem 115201 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220530153940.parquet tem 87481 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220531210440.parquet tem 145341 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220531232936.parquet tem 78581 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220601013638.parquet tem 94141 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220601052339.parquet tem 173101 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220601081739.parquet tem 151161 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220601105338.parquet tem 92041 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220601130038.parquet tem 91541 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220601151236.parquet tem 91221 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220601171638.parquet tem 92541 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220601211638.parquet tem 122721 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220601234638.parquet tem 120441 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220602054241.parquet tem 221201 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220602094841.parquet tem 255661 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220602131639.parquet tem 135721 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220602153239.parquet tem 112041 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220602183539.parquet tem 119161 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220602214039.parquet tem 112981 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220602233438.parquet tem 71161 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220603013339.parquet tem 73981 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220603051739.parquet tem 163821 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220603084040.parquet tem 180741 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220603104038.parquet tem 82781 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220603123639.parquet tem 75541 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220603142239.parquet tem 84801 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220604101401.parquet tem 78001 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220604101402.parquet tem 122561 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220604101403.parquet tem 108681 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20220604101404.parquet tem 118621 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221030192539.parquet tem 81721 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221030223441.parquet tem 177161 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221031014640.parquet tem 89021 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221031050541.parquet tem 150401 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221031082141.parquet tem 155681 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221031113541.parquet tem 154781 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221031141941.parquet tem 139581 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221031194239.parquet tem 160881 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221031225444.parquet tem 187881 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221101050341.parquet tem 190881 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221101183944.parquet tem 116161 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221101231844.parquet tem 163601 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221229230544.parquet tem 186641 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221230025742.parquet tem 118201 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221231041001.parquet tem 12421 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20221231041002.parquet tem 68321 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20230713080505.parquet tem 118301 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20230713080506.parquet tem 164781 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20230713080507.parquet tem 137861 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20230713105147.parquet tem 121141 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20230713130144.parquet tem 98361 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20230713150643.parquet tem 82841 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20230713170043.parquet tem 65801 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20230713225344.parquet tem 122681 linhas.
# Arquivo TCRF_ARCHIVE_06120033_20230714010444.parquet tem 115101 linhas.
# O número total de linhas em todos os arquivos é: 8456692

# %% [markdown]
# #### Remoção de linhas duplicadas e remoção de valores das colunas de data

# %%
def remove_duplicates_except_record_time(dask_df):
    """
    Remove linhas duplicadas com base em todas as colunas, exceto 'record_time'.

    Parâmetros:
    - dask_df: DataFrame Dask de entrada.

    Retorna:
    - DataFrame Dask com linhas duplicadas removidas.
    """

    # Crie uma lista de colunas a serem consideradas ao identificar duplicatas
    columns_to_consider = [col for col in dask_df.columns if col != 'record_time']

    # Use o método drop_duplicates do Dask para remover duplicatas com base nas colunas especificadas
    #Mantém o primeiro valor duplicado por default
    unique_df = dask_df.drop_duplicates(subset=columns_to_consider)

    return unique_df

# Uso da função
unique_df = remove_duplicates_except_record_time(resulting_df)

# %%
# Preenchendo com NaN as datas vazias
data_df = unique_df

columns_to_fill = ['dateYear-1', 'dateMonth-1', 'dateDay-1']
data_df[columns_to_fill] = data_df[columns_to_fill].fillna(0)

# %%
data_df
# Out:
# Dask DataFrame Structure:
#               recording_time dateDay-1 dateMonth-1 dateYear-1 phaseOfFlight-1 message0418DAA-1 message0422DAA-1 bleedFavTmCmd-1a bleedFavTmCmd-1b bleedFavTmCmd-2a bleedFavTmCmd-2b bleedFavTmFbk-1a bleedFavTmFbk-1b bleedFavTmFbk-2b bleedHprsovCmdStatus-1a bleedHprsovCmdStatus-1b bleedHprsovCmdStatus-2a bleedHprsovCmdStatus-2b bleedHprsovOpPosStatus-1a bleedHprsovOpPosStatus-1b bleedHprsovOpPosStatus-2a bleedHprsovOpPosStatus-2b bleedMonPress-1a bleedMonPress-1b bleedMonPress-2a bleedMonPress-2b bleedOnStatus-1a bleedOnStatus-1b
# npartitions=1
#                        int64   float64     float64    float64         float64          float64          float64          float64          float64          float64          float64          float64          float64          float64                 float64                 float64                 float64                 float64                   float64                   float64                   float64                   float64          float64          float64          float64          float64          float64          float64
#                          ...       ...         ...        ...             ...              ...              ...              ...              ...              ...              ...              ...              ...              ...                     ...                     ...                     ...                     ...                       ...                       ...                       ...                       ...              ...              ...              ...              ...              ...              ...
# Dask Name: assign, 262 graph layers

# %% [markdown]
# ### Salvando o DataFrame agregado em um novo arquivo parquet

# %%
# Exportando o parquet
data_df.to_parquet('failure_window.parquet')
